# %% [markdown]
# ## Exercise 2

# %% [markdown]
# For this exercise , you will be working with the [Titanic Data Set from Kaggle](https://www.kaggle.com/c/titanic). This is a very famous data set and very often is a student's first step in Data Analytics!
#
# The Dataset has been given to you on D2L. You need to download the .csv file from your assignment folder. The above link is just for a reference story about the data.

# %% [markdown]
# 1- For this assignment, you need to perform explorotary data analysis and answer at least three hypotheses based on the dataset. You may need to use your knowledge of statiscts to analyze this data.
#
# Here are three possible hypotheses that you can define for this dataset (you can define your own hypotheses as well):
#
# - Determine if the survival rate is associated to the class of passenger
# - Determine if the survival rate is associated to the gender
# - Determine the survival rate is associated to the age
#
#
#
# 2- For each hypothesis, you need to make at least one plot.
#
# 3- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 2 of your assignment, you need to submit one jupyter notebook file and one pdf file.
#
# This will be your first end to end data analysis project. For this assignment, you will be graded on you overall analysis, and your final report.
#
# 4- Push your code and project to github and provide the link to your code here.

# %% [markdown]
# Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('../Data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#Bar chart with the amount of survivors based on class.
#Easy to see that the first class suvived more, compared to third class.
sns.barplot(x = 'Pclass', y = 'Survived', data = df)
plt.savefig('../Results/survivors based on class.png')

# %%
#Bar chart for Survived and gender.
sns.barplot(x = 'Sex', y = 'Survived', data = df)
plt.savefig('../Results/Survived and gender.png')

# %%
#Bar chart for age and survivers.
#Age was not a really big deal while saving the passenger.
sns.barplot(x = 'Survived', y = 'Age', data = df)
plt.savefig('../Results/Age and survivers.png')

# %%
#P-Value for survival rate and class of passenger = -0.338481 (negative relation)
#WE have enoth evidency to support Ho.
#P-Value for survival rate and gender = 
#WE have enoth evidency to support Ho.
#P-Value for survival rate and age = -0.077221 (negative relation)
#WE have enoth evidency to support Ho.s
